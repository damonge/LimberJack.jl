# %%
import numpy as np
import matplotlib.pyplot as plt
ccl_results = np.load("test_results.npz")
LB_results = np.load("test/test_output.npz")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 ccl_results = np.load("test/test_result")
#       4 LB_results = np.load("test/test_output.npz")
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test/test_result'

# %%
ls = [10.0, 30.0, 100.0, 300.0, 1000]
plt.plot(ls, LB_results["cl_gg_eishu"])
plt.plot(ls, ccl_results["cl_gg_eishu"])

# %%
ls = [10.0, 30.0, 100.0, 300.0]
plt.plot(ls, LB_results["cl_gg_eishu_nonlin"])
plt.plot(ls, ccl_results["cl_gg_eishu_nonlin"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 2
#       1 ls = [10.0, 30.0, 100.0, 300.0]
# ----> 2 plt.plot(ls, LB_results["cl_gg_eishu_nonlin"])
#       3 plt.plot(ls, ccl_results["cl_gg_eishu_nonlin"])
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:2740, in plot(scalex, scaley, data, *args, **kwargs)
#    2738 @_copy_docstring_and_deprecators(Axes.plot)
#    2739 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2740     return gca().plot(
#    2741         *args, scalex=scalex, scaley=scaley,
#    2742         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (5,)

# %%
fig, axis = plt.subplots(4, 2, figsize=(10,10), gridspec_kw={'height_ratios': [1, 3, 1, 3]})
fig.subplots_adjust(hspace=0)
fig.subplots_adjust(wspace=0)

axis[0,0].plot(ls, abs(ccl_results["pk_EisHu"]/LB_results["pk_EisHu"]-1),
               'k-', label="CCL (classy)")
axis[0,0].set_ylim(0, 0.002)
axis[0,0].set_xscale("log")
axis[0,0].grid(True)

axis[1,0].plot(ls, LB_results["pk_EisHu"], label="LimberJack")
axis[1,0].plot(ls, ccl_results["pk_EisHu"], label="CCL (classy)")
axis[1,0].legend(loc=3)
axis[1,0].set_ylabel("P(k,z)")
axis[1,0].set_title("Linear Eisenstein & Hu", y=0.9)
axis[1,0].set_xscale("log")
axis[1,0].set_yscale("log")

axis[0,1].plot(ls, abs(ccl_results["pk_EisHu_nonlin"]/LB_results["pk_EisHu_nonlin"]-1),
               'k-', label="CCL (classy)")
axis[0,1].set_ylim(0, 0.002)
axis[0,1].grid(True)
axis[0,1].set_xscale("log")
axis[0,1].yaxis.set_ticklabels([])

axis[1,1].plot(ls, LB_results["pk_EisHu_nonlin"])
axis[1,1].plot(ls, ccl_results["pk_EisHu_nonlin"])
axis[1,1].set_title("Non-linear Eisenstein & Hu", y=0.9)
axis[1,1].set_xscale("log")
axis[1,1].set_yscale("log")
axis[1,1].set_yticks([])

axis[2,0].plot(ls, abs(ccl_results["pk_emul"]/LB_results["pk_emul"]-1),
               'k-', label="CCL (classy)")
axis[2,0].set_ylim(0, 0.06)
axis[2,0].set_xscale("log")
axis[2,0].grid(True)

axis[3,0].plot(ls, LB_results["pk_emul"])
axis[3,0].plot(ls, ccl_results["pk_emul"])
axis[3,0].set_ylabel("P(k,z)")
axis[3,0].set_xlabel("k")
axis[3,0].set_title("Linear emulator", y=0.9)
axis[3,0].set_xscale("log")
axis[3,0].set_yscale("log")


axis[2,1].plot(ls, abs(ccl_results["pk_emul_nonlin"]/LB_results["pk_emul_nonlin"]-1),
               'k-', label="CCL (classy)")
axis[2,1].set_ylim(0, 0.06)
axis[2,1].grid(True)
axis[2,1].set_xscale("log")
axis[2,1].yaxis.set_ticklabels([])

axis[3,1].plot(ls, LB_results["pk_emul_nonlin"])
axis[3,1].plot(ls, ccl_results["pk_emul_nonlin"])
axis[3,1].set_xlabel("k")
axis[3,1].set_title("Non-linear emulator", y=0.9)
axis[3,1].set_xscale("log")
axis[3,1].set_yscale("log")
axis[3,1].set_yticks([]);

plt.savefig("/mnt/c/Users/jaime/Desktop/Growth_with_RSDs/Pk_acc.pdf", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 5
#       2 fig.subplots_adjust(hspace=0)
#       3 fig.subplots_adjust(wspace=0)
# ----> 5 axis[0,0].plot(ls, abs(ccl_results["pk_EisHu"]/LB_results["pk_EisHu"]-1),
#       6                'k-', label="CCL (classy)")
#       7 axis[0,0].set_ylim(0, 0.002)
#       8 axis[0,0].set_xscale("log")
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (40,)
