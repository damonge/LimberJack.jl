# %%
using Turing
using LimberJack
using LinearAlgebra
using CSV
using NPZ
using Plots
using FITSIO
using Random
using GaussianProcess

# %%
files = npzread("../data/DESY1_cls/Cls_meta.npz")
Cls_meta = cls_meta(files)
cov_tot = files["cov"]
data_vector = files["cls"]

fid_cosmo = Cosmology()
N = 100
latent_x = Vector(0:0.3:3)
x = Vector(range(0., stop=3., length=N));

# %%
struct Determin{T<:Any} <: ContinuousUnivariateDistribution
  val::T
end

Distributions.rand(rng::AbstractRNG, d::Determin) = d.val
Distributions.logpdf(d::Determin, x::T) where T<:Real = zero(x)
Bijectors.bijector(d::Determin) = Identity{0}()

# %%
@model function model(data_vector; cov_tot=cov_tot, fid_cosmo=fid_cosmo,
                      latent_x=latent_x, x=x)
    eta ~ Uniform(0.0, 0.5)
    l ~ Uniform(0.1, 3)
    latent_N = length(latent_x)
    v ~ MvNormal(zeros(latent_N), ones(latent_N))
    
    Ωm ~ Uniform(0.1, 0.9)
    Ωb = 0.05 #~ Uniform(0.03, 0.07)
    h ~ Uniform(0.55, 0.91)
    s8 = 0.811
    ns = 0.96 
    
    nuisances = Dict()
    
    mu = fid_cosmo.Dz(vec(latent_x))
    K = sqexp_cov_fn(latent_x; eta=eta, l=l)
    latent_gp = latent_GP(mu, v, K)
    gp = conditional(latent_x, x, latent_gp, sqexp_cov_fn;
                      eta=eta, l=l)
    gp_val ~ Determin(gp)
    
    cosmology = LimberJack.Cosmology(Ωm, Ωb, h, ns, s8,
                                     tk_mode="EisHu",
                                     Pk_mode="Halofit", 
                                     custom_Dz=gp)
    
    theory = Theory(cosmology, Cls_meta, files;
                    Nuisances=nuisances).cls
    data_vector ~ MvNormal(theory, cov_tot)
end;

# %%
cycles = 10
iterations = 50
TAP = 0.60
adaptation = 10
#nchains = Threads.nthreads()


# Start sampling.
folpath = "../chains"
folname = string("DES_test_gp_", "TAP", TAP)
folname = joinpath(folpath, folname)

mkdir(folname)
println("Created new folder")

for i in 1:cycles
    if i == 1
        chain = sample(model(data_vector), NUTS(adaptation, TAP), 
                       iterations, progress=true; save_state=true)
    else
        old_chain = read(joinpath(folname, string("chain_", i-1, ".jls")), Chains)
        chain = sample(model(data_vector), NUTS(adaptation, TAP), 
                       iterations, progress=true; save_state=true,
                       resume_from=old_chain)
    end 
    write(joinpath(folname, string("chain_", i,".jls")), chain)
    CSV.write(joinpath(folname, string("chain_", i,".csv")), chain)
end
# Out:
# Created new folder
# MethodError: no method matching vectorize(::Determin{Vector{Float64}}, ::Vector{Float64})
# Closest candidates are:
#   vectorize(::UnivariateDistribution, ::Real) at ~/.julia/packages/DynamicPPL/SgzCy/src/utils.jl:83
#   vectorize(::MultivariateDistribution, ::AbstractVector{<:Real}) at ~/.julia/packages/DynamicPPL/SgzCy/src/utils.jl:84
#
# Stacktrace:
#   [1] push!(vi::DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, vn::AbstractPPL.VarName{:gp_val, Tuple{}}, r::Vector{Float64}, dist::Determin{Vector{Float64}}, gidset::Set{DynamicPPL.Selector})
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/SgzCy/src/varinfo.jl:1070
#   [2] push!(vi::DynamicPPL.ThreadSafeVarInfo{DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, Vector{Base.RefValue{Float64}}}, vn::AbstractPPL.VarName{:gp_val, Tuple{}}, r::Vector{Float64}, dist::Determin{Vector{Float64}}, gidset::Set{DynamicPPL.Selector})
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/SgzCy/src/threadsafe.jl:96
#   [3] push!(vi::DynamicPPL.ThreadSafeVarInfo{DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, Vector{Base.RefValue{Float64}}}, vn::AbstractPPL.VarName{:gp_val, Tuple{}}, r::Vector{Float64}, dist::Determin{Vector{Float64}})
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/SgzCy/src/varinfo.jl:1029
#   [4] push!(vi::DynamicPPL.ThreadSafeVarInfo{DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, Vector{Base.RefValue{Float64}}}, vn::AbstractPPL.VarName{:gp_val, Tuple{}}, r::Vector{Float64}, dist::Determin{Vector{Float64}}, spl::DynamicPPL.SampleFromPrior)
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/SgzCy/src/varinfo.jl:1044
#   [5] assume(rng::Random._GLOBAL_RNG, spl::DynamicPPL.SampleFromPrior, dist::Determin{Vector{Float64}}, vn::AbstractPPL.VarName{:gp_val, Tuple{}}, vi::DynamicPPL.ThreadSafeVarInfo{DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, Vector{Base.RefValue{Float64}}})
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/SgzCy/src/context_implementations.jl:145
#   [6] _tilde
#     @ ~/.julia/packages/DynamicPPL/SgzCy/src/context_implementations.jl:62 [inlined]
#   [7] tilde
#     @ ~/.julia/packages/DynamicPPL/SgzCy/src/context_implementations.jl:23 [inlined]
#   [8] tilde_assume(rng::Random._GLOBAL_RNG, ctx::DynamicPPL.DefaultContext, sampler::DynamicPPL.SampleFromPrior, right::Determin{Vector{Float64}}, vn::AbstractPPL.VarName{:gp_val, Tuple{}}, inds::Tuple{}, vi::DynamicPPL.ThreadSafeVarInfo{DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, Vector{Base.RefValue{Float64}}})
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/SgzCy/src/context_implementations.jl:55
#   [9] #5
#     @ ./In[12]:21 [inlined]
#  [10] (::var"#5#6")(__rng__::Random._GLOBAL_RNG, __model__::DynamicPPL.Model{var"#5#6", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, __varinfo__::DynamicPPL.ThreadSafeVarInfo{DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, Vector{Base.RefValue{Float64}}}, __sampler__::DynamicPPL.SampleFromPrior, __context__::DynamicPPL.DefaultContext, data_vector::Vector{Float64}, cov_tot::Matrix{Float64}, fid_cosmo::Cosmology, latent_x::Vector{Float64}, x::Vector{Float64})
#     @ Main ./none:0
#  [11] macro expansion
#     @ ~/.julia/packages/DynamicPPL/SgzCy/src/model.jl:0 [inlined]
#  [12] _evaluate
#     @ ~/.julia/packages/DynamicPPL/SgzCy/src/model.jl:154 [inlined]
#  [13] evaluate_threadsafe(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{var"#5#6", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, varinfo::DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, sampler::DynamicPPL.SampleFromPrior, context::DynamicPPL.DefaultContext)
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/SgzCy/src/model.jl:144
#  [14] Model
#     @ ~/.julia/packages/DynamicPPL/SgzCy/src/model.jl:94 [inlined]
#  [15] VarInfo
#     @ ~/.julia/packages/DynamicPPL/SgzCy/src/varinfo.jl:126 [inlined]
#  [16] VarInfo
#     @ ~/.julia/packages/DynamicPPL/SgzCy/src/varinfo.jl:125 [inlined]
#  [17] step(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{var"#5#6", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, spl::DynamicPPL.Sampler{MH{(), NamedTuple{(), Tuple{}}}}; resume_from::Nothing, kwargs::Base.Pairs{Symbol, Bool, Tuple{Symbol}, NamedTuple{(:save_state,), Tuple{Bool}}})
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/SgzCy/src/sampler.jl:73
#  [18] macro expansion
#     @ ~/.julia/packages/AbstractMCMC/oou1a/src/sample.jl:97 [inlined]
#  [19] macro expansion
#     @ ~/.julia/packages/ProgressLogging/6KXlp/src/ProgressLogging.jl:328 [inlined]
#  [20] (::AbstractMCMC.var"#20#21"{Bool, String, Nothing, Int64, Int64, Base.Pairs{Symbol, Bool, Tuple{Symbol}, NamedTuple{(:save_state,), Tuple{Bool}}}, Random._GLOBAL_RNG, DynamicPPL.Model{var"#5#6", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{MH{(), NamedTuple{(), Tuple{}}}}, Int64, Int64})()
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/oou1a/src/logging.jl:11
#  [21] with_logstate(f::Function, logstate::Any)
#     @ Base.CoreLogging ./logging.jl:511
#  [22] with_logger(f::Function, logger::LoggingExtras.TeeLogger{Tuple{LoggingExtras.EarlyFilteredLogger{ConsoleProgressMonitor.ProgressLogger, AbstractMCMC.var"#1#3"{Module}}, LoggingExtras.EarlyFilteredLogger{Base.CoreLogging.SimpleLogger, AbstractMCMC.var"#2#4"{Module}}}})
#     @ Base.CoreLogging ./logging.jl:623
#  [23] with_progresslogger(f::Function, _module::Module, logger::Base.CoreLogging.SimpleLogger)
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/oou1a/src/logging.jl:34
#  [24] macro expansion
#     @ ~/.julia/packages/AbstractMCMC/oou1a/src/logging.jl:10 [inlined]
#  [25] mcmcsample(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{var"#5#6", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, sampler::DynamicPPL.Sampler{MH{(), NamedTuple{(), Tuple{}}}}, N::Int64; progress::Bool, progressname::String, callback::Nothing, discard_initial::Int64, thinning::Int64, chain_type::Type, kwargs::Base.Pairs{Symbol, Bool, Tuple{Symbol}, NamedTuple{(:save_state,), Tuple{Bool}}})
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/oou1a/src/sample.jl:88
#  [26] sample(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{var"#5#6", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, sampler::DynamicPPL.Sampler{MH{(), NamedTuple{(), Tuple{}}}}, N::Int64; chain_type::Type, resume_from::Nothing, progress::Bool, kwargs::Base.Pairs{Symbol, Bool, Tuple{Symbol}, NamedTuple{(:save_state,), Tuple{Bool}}})
#     @ Turing.Inference ~/.julia/packages/Turing/uAz5c/src/inference/Inference.jl:156
#  [27] #sample#2
#     @ ~/.julia/packages/Turing/uAz5c/src/inference/Inference.jl:142 [inlined]
#  [28] #sample#1
#     @ ~/.julia/packages/Turing/uAz5c/src/inference/Inference.jl:132 [inlined]
#  [29] top-level scope
#     @ ./In[14]:18
#  [30] eval
#     @ ./boot.jl:373 [inlined]
#  [31] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1196
