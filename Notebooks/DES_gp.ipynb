# %%
using Turing
using LimberJack
using LinearAlgebra
using CSV
using NPZ
using Plots
using FITSIO
using Random
using GaussianProcess

# %%
files = npzread("../data/DESY1_cls/gcgc_gcwl_wlwl.npz")
cov_tot = files["cov"]
data_vector = files["cls"]

fid_cosmo = Cosmology()
N = 100
latent_x = Vector(0:0.3:3)
x = Vector(range(0., stop=3., length=N));

# %%
@model function model(data_vector; cov_tot=cov_tot, fid_cosmo=fid_cosmo,
                      latent_x=latent_x, x=x)
    eta ~ Uniform(0.0, 0.5)
    l ~ Uniform(0.1, 3)
    latent_N = length(latent_x)
    v ~ MvNormal(zeros(latent_N), ones(latent_N))
    
    Ωm ~ Uniform(0.1, 0.9)
    Ωb = 0.05 #~ Uniform(0.03, 0.07)
    h ~ Uniform(0.55, 0.91)
    s8 = 0.811
    ns = 0.96 
    
    nuisances = Dict()
    
    mu = fid_cosmo.Dz(vec(latent_x))
    K = sqexp_cov_fn(latent_x; eta=eta, l=l)
    latent_gp = latent_GP(mu, v, K)
    gp = conditional(latent_x, x, latent_gp, sqexp_cov_fn;
                      eta=eta, l=l)
    
    cosmology = LimberJack.Cosmology(Ωm, Ωb, h, ns, s8,
                                     tk_mode="EisHu",
                                     Pk_mode="Halofit", 
                                     custom_Dz=gp)
    
    theory = Theory(cosmology, files;
                    Nuisances=nuisances)
    data_vector ~ MvNormal(theory, cov_tot)
end;

# %%
cycles = 10
iterations = 50
TAP = 0.60
adaptation = 10
#nchains = Threads.nthreads()


# Start sampling.
folpath = "../chains"
folname = string("DES_test_gp_", "TAP", TAP)
folname = joinpath(folpath, folname)

mkdir(folname)
println("Created new folder")

for i in 1:cycles
    if i == 1
        chain = sample(model(data_vector), NUTS(adaptation, TAP), 
                       iterations, progress=true; save_state=true)
    else
        old_chain = read(joinpath(folname, string("chain_", i-1, ".jls")), Chains)
        chain = sample(model(data_vector), NUTS(adaptation, TAP), 
                       iterations, progress=true; save_state=true,
                       resume_from=old_chain)
    end 
    write(joinpath(folname, string("chain_", i,".jls")), chain)
    CSV.write(joinpath(folname, string("chain_", i,".csv")), chain)
end
# Out:
# Created new folder
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /home/jaime/.julia/packages/AdvancedHMC/MIxdK/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /home/jaime/.julia/packages/AdvancedHMC/MIxdK/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /home/jaime/.julia/packages/AdvancedHMC/MIxdK/src/hamiltonian.jl:47
# InterruptException:
#
# Stacktrace:
#   [1] _chol!(A::Matrix{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Float64}, Float64, 8}}, #unused#::Type{UpperTriangular})
#     @ LinearAlgebra /opt/julia-1.7.0/share/julia/stdlib/v1.7/LinearAlgebra/src/cholesky.jl:205
#   [2] #cholesky!#138
#     @ /opt/julia-1.7.0/share/julia/stdlib/v1.7/LinearAlgebra/src/cholesky.jl:265 [inlined]
#   [3] cholesky!(A::Matrix{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Float64}, Float64, 8}}, ::Val{false}; check::Bool)
#     @ LinearAlgebra /opt/julia-1.7.0/share/julia/stdlib/v1.7/LinearAlgebra/src/cholesky.jl:298
#   [4] #cholesky#143
#     @ /opt/julia-1.7.0/share/julia/stdlib/v1.7/LinearAlgebra/src/cholesky.jl:394 [inlined]
#   [5] cholesky (repeats 2 times)
#     @ /opt/julia-1.7.0/share/julia/stdlib/v1.7/LinearAlgebra/src/cholesky.jl:394 [inlined]
#   [6] PDMat
#     @ ~/.julia/packages/PDMats/G0Prn/src/pdmat.jl:19 [inlined]
#   [7] convert(#unused#::Type{PDMats.PDMat{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Float64}, Float64, 8}}}, a::PDMats.PDMat{Float64, Matrix{Float64}})
#     @ PDMats ~/.julia/packages/PDMats/G0Prn/src/pdmat.jl:24
#   [8] convert
#     @ ~/.julia/packages/PDMats/G0Prn/src/pdmat.jl:25 [inlined]
#   [9] MvNormal
#     @ ~/.julia/packages/Distributions/jFoHB/src/multivariate/mvnormal.jl:202 [inlined]
#  [10] MvNormal(μ::Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Float64}, Float64, 8}}, Σ::Matrix{Float64})
#     @ Distributions ~/.julia/packages/Distributions/jFoHB/src/multivariate/mvnormal.jl:211
#  [11] #11
#     @ ./In[16]:29 [inlined]
#  [12] (::var"#11#12")(__rng__::Random._GLOBAL_RNG, __model__::DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, __varinfo__::DynamicPPL.ThreadSafeVarInfo{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Float64}, Float64, 8}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Float64}, Float64, 8}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{Dynamic ...
#     @ Main ./none:0
#  [13] macro expansion
#     @ ~/.julia/packages/DynamicPPL/SgzCy/src/model.jl:0 [inlined]
#  [14] _evaluate
#     @ ~/.julia/packages/DynamicPPL/SgzCy/src/model.jl:154 [inlined]
#  [15] evaluate_threadsafe
#     @ ~/.julia/packages/DynamicPPL/SgzCy/src/model.jl:144 [inlined]
#  [16] (::DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}})(rng::Random._GLOBAL_RNG, varinfo::DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Float64}, Float64, 8}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Float64}, Float64, 8}}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{Dy ...
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/SgzCy/src/model.jl:94
#  [17] Model
#     @ ~/.julia/packages/DynamicPPL/SgzCy/src/model.jl:98 [inlined]
#  [18] f
#     @ ~/.julia/packages/Turing/uAz5c/src/core/ad.jl:111 [inlined]
#  [19] chunk_mode_gradient!(result::Vector{Float64}, f::Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, x::Vector{Float64}, cfg::ForwardDiff.GradientConfig{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Float64}, Float64, 8, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{A ...
#     @ ForwardDiff ~/.julia/packages/ForwardDiff/PBzup/src/gradient.jl:150
#  [20] gradient!
#     @ ~/.julia/packages/ForwardDiff/PBzup/src/gradient.jl:39 [inlined]
#  [21] gradient!(result::Vector{Float64}, f::Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, x::Vector{Float64}, cfg::ForwardDiff.GradientConfig{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext}, Float64}, Float64, 8, Vector{ForwardDiff.Dual{ForwardDiff.Tag{Turing.Core.var"#f#7"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL. ...
#     @ ForwardDiff ~/.julia/packages/ForwardDiff/PBzup/src/gradient.jl:35
#  [22] gradient_logp(::Turing.Core.ForwardDiffAD{40}, θ::Vector{Float64}, vi::DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, model::DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, sampler::DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, ctx::DynamicPPL.DefaultContext)
#     @ Turing.Core ~/.julia/packages/Turing/uAz5c/src/core/ad.jl:121
#  [23] gradient_logp (repeats 2 times)
#     @ ~/.julia/packages/Turing/uAz5c/src/core/ad.jl:83 [inlined]
#  [24] ∂logπ∂θ
#     @ ~/.julia/packages/Turing/uAz5c/src/inference/hmc.jl:482 [inlined]
#  [25] ∂H∂θ
#     @ ~/.julia/packages/AdvancedHMC/MIxdK/src/hamiltonian.jl:31 [inlined]
#  [26] macro expansion
#     @ ~/.julia/packages/UnPack/EkESO/src/UnPack.jl:100 [inlined]
#  [27] step(lf::AdvancedHMC.Leapfrog{Float64}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, Turing.Inference.var"#logπ#54"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}}, Turing.Inference.var"#∂logπ∂θ#53"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}}}, z::AdvancedHMC.PhasePoint{Vector{Float64}, AdvancedHMC.DualValue{Float64, Vector{Float64}}}, n_steps::Int64; fwd::Bool, full_trajectory::Val{false})
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/MIxdK/src/integrator.jl:88
#  [28] step (repeats 2 times)
#     @ ~/.julia/packages/AdvancedHMC/MIxdK/src/integrator.jl:66 [inlined]
#  [29] A
#     @ ~/.julia/packages/AdvancedHMC/MIxdK/src/trajectory.jl:793 [inlined]
#  [30] find_good_stepsize(rng::Random._GLOBAL_RNG, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, Turing.Inference.var"#logπ#54"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}}, Turing.Inference.var"#∂logπ∂θ#53"{DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}}}, θ::Vector{Float64}; max_n_iters::Int64)
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/MIxdK/src/trajectory.jl:852
#  [31] #find_good_stepsize#13
#     @ ~/.julia/packages/AdvancedHMC/MIxdK/src/trajectory.jl:873 [inlined]
#  [32] find_good_stepsize
#     @ ~/.julia/packages/AdvancedHMC/MIxdK/src/trajectory.jl:873 [inlined]
#  [33] initialstep(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, spl::DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, vi::DynamicPPL.TypedVarInfo{NamedTuple{(:eta, :l, :v, :Ωm, :h), Tuple{DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:eta, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:eta, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:l, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:l, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v, Tuple{}}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:Ωm, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:Ωm, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h, Tuple{}}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h, Tuple{}}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}}, Float64}; init_params::Nothing, nadapts::Int64, kwargs::Base.Pairs{Symbol, Bool, Tuple{Symbol}, NamedTuple{(:save_state,), Tuple{Bool}}})
#     @ Turing.Inference ~/.julia/packages/Turing/uAz5c/src/inference/hmc.jl:194
#  [34] step(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, spl::DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}; resume_from::Nothing, kwargs::Base.Pairs{Symbol, Integer, Tuple{Symbol, Symbol}, NamedTuple{(:nadapts, :save_state), Tuple{Int64, Bool}}})
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/SgzCy/src/sampler.jl:91
#  [35] macro expansion
#     @ ~/.julia/packages/AbstractMCMC/oou1a/src/sample.jl:97 [inlined]
#  [36] macro expansion
#     @ ~/.julia/packages/ProgressLogging/6KXlp/src/ProgressLogging.jl:328 [inlined]
#  [37] (::AbstractMCMC.var"#20#21"{Bool, String, Nothing, Int64, Int64, Base.Pairs{Symbol, Integer, Tuple{Symbol, Symbol}, NamedTuple{(:nadapts, :save_state), Tuple{Int64, Bool}}}, Random._GLOBAL_RNG, DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Int64})()
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/oou1a/src/logging.jl:11
#  [38] with_logstate(f::Function, logstate::Any)
#     @ Base.CoreLogging ./logging.jl:511
#  [39] with_logger(f::Function, logger::LoggingExtras.TeeLogger{Tuple{LoggingExtras.EarlyFilteredLogger{ConsoleProgressMonitor.ProgressLogger, AbstractMCMC.var"#1#3"{Module}}, LoggingExtras.EarlyFilteredLogger{Base.CoreLogging.SimpleLogger, AbstractMCMC.var"#2#4"{Module}}}})
#     @ Base.CoreLogging ./logging.jl:623
#  [40] with_progresslogger(f::Function, _module::Module, logger::Base.CoreLogging.SimpleLogger)
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/oou1a/src/logging.jl:34
#  [41] macro expansion
#     @ ~/.julia/packages/AbstractMCMC/oou1a/src/logging.jl:10 [inlined]
#  [42] mcmcsample(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, sampler::DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; progress::Bool, progressname::String, callback::Nothing, discard_initial::Int64, thinning::Int64, chain_type::Type, kwargs::Base.Pairs{Symbol, Integer, Tuple{Symbol, Symbol}, NamedTuple{(:nadapts, :save_state), Tuple{Int64, Bool}}})
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/oou1a/src/sample.jl:88
#  [43] sample(rng::Random._GLOBAL_RNG, model::DynamicPPL.Model{var"#11#12", (:data_vector, :cov_tot, :fid_cosmo, :latent_x, :x), (:cov_tot, :fid_cosmo, :latent_x, :x), (), Tuple{Vector{Float64}, Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}, Tuple{Matrix{Float64}, Cosmology, Vector{Float64}, Vector{Float64}}}, sampler::DynamicPPL.Sampler{NUTS{Turing.Core.ForwardDiffAD{40}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; chain_type::Type, resume_from::Nothing, progress::Bool, nadapts::Int64, discard_adapt::Bool, discard_initial::Int64, kwargs::Base.Pairs{Symbol, Bool, Tuple{Symbol}, NamedTuple{(:save_state,), Tuple{Bool}}})
#     @ Turing.Inference ~/.julia/packages/Turing/uAz5c/src/inference/hmc.jl:140
#  [44] #sample#2
#     @ ~/.julia/packages/Turing/uAz5c/src/inference/Inference.jl:142 [inlined]
#  [45] #sample#1
#     @ ~/.julia/packages/Turing/uAz5c/src/inference/Inference.jl:132 [inlined]
#  [46] top-level scope
#     @ ./In[18]:18
#  [47] eval
#     @ ./boot.jl:373 [inlined]
#  [48] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1196
