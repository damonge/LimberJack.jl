# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pyccl as ccl
import os
import getdist
from getdist import plots, MCSamples
# %matplotlib inline

# %%
names_planck  = ['ns', 'h', 'Ωm', 'Ωb', 's8']
labels_planck = [r'n_s', r'h', r'\Omega_{\rm{m}}', 
                 r'\Omega_{\rm{b}}', r'\sigma_{\rm{8}}']

planck1 = np.loadtxt('/home/jaime/Master/PLANCK/Planck_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_post_zre6p5_1.txt')
planck2 = np.loadtxt('/home/jaime/Master/PLANCK/Planck_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_post_zre6p5_2.txt')
planck3 = np.loadtxt('/home/jaime/Master/PLANCK/Planck_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_post_zre6p5_3.txt')
planck4 = np.loadtxt('/home/jaime/Master/PLANCK/Planck_TTTEEE_lowl_lowE/base_plikHM_TTTEEE_lowl_lowE_post_zre6p5_4.txt')

planck_tot = np.concatenate((planck1, planck2, planck3, planck4), axis=0)

planck_params = []
for item in planck_tot:
    planck_params.append([item[7], item[29]/100, item[31], item[2]/(item[29]/100)**2, item[34]])
planck_params = np.array(planck_params)
planck_samples = MCSamples(samples=planck_params, names = names_planck, labels = labels_planck, label= r'$Planck$ 2018',
                    weights=np.transpose(planck_tot)[0],loglikes=np.transpose(planck_tot)[1])
# Out:
# Removed no burn in

# %%
path = '/home/jaime/PhD/LimberJack.jl/chains/'
HaloWm_MH = pd.read_csv(path+'Halofit_test_MH/chain.csv')
HaloWm_HMC = pd.read_csv(path+'Halofit_test_stpsz_0.005_smpls_10/chain.csv')
DESgs = pd.read_csv(path+'Cl_DESgs_test_chain.csv')
EisHu = pd.read_csv(path+'Cl_EisHu_chain_full.csv')
new_EisHu = pd.read_csv(path+'New_Cl_EisHu_chain.csv')
new_Halofit = pd.read_csv(path+'New_cl_Halofit_chain.csv')
EisHu_min_mh = pd.read_csv(path+'Cl_EisHu_mim_chain_1000_MH.csv')
EisHu_min_NUTS = pd.read_csv(path+'Cl_EisHu_mim_chain_1000_1000_tap_065_.csv')

# %%
labels_dict = {'ns': 'n_s',
               'h': 'h',
               'Ωm': '\Omega_m',
               'Ωb': '\Omega_b',
               's8': '\sigma_8',
               'S8': 'S_8'}
names_All = ['ns', 'h', 'Omega_m', 'Omega_b', 's80', 'S80']
ranges = {'h': [0.6, 0.8], 'Ωm':[0.1, 0.5],  's8': [0.7, 1.0]}

# %%
def make_samples(file, names, ranges, label):
    namess = []
    labels = []
    samples = []
    for name in names:
        if name in np.array(file.keys()):
            namess.append(name) 
            labels.append(labels_dict[name]) 
            samples.append(np.array(file[name]))
    return MCSamples(samples=samples, names=namess, labels=labels, label=label, ranges=ranges)
                    #settings={'mult_bias_correction_order':0,'smooth_scale_2D':0.2, 'smooth_scale_1D':0.2})

# %%
DESgs_samples = make_samples(DESgs, ['h', 'Ωm', 's8'], ranges, r'$DES_gs$')
EisHu_samples = make_samples(EisHu, ['ns', 'h', 'Ωm', 'Ωb', 's8'], ranges, r'$EisHu$')
new_EisHu_samples = make_samples(new_EisHu, ['h', 'Ωm', 's8'], ranges, r'$EisHu$')
new_Halofit_samples = make_samples(new_Halofit, ['h', 'Ωm', 's8'], ranges, r'$Halofit$')
EisHu_min_mh_samples = make_samples(EisHu_min_mh, ['Ωm'], ranges, r'$EisHu$ min MH')
EisHu_min_NUTS_samples = make_samples(EisHu_min_NUTS, ['Ωm'], ranges, r'$EisHu$ min NUTS')
HaloWm_MH_samples = make_samples(HaloWm_MH, ['Ωm'], ranges, 'HaloWm_HM')
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
g = plots.getSubplotPlotter(subplot_size=2.5)
g.triangle_plot([DESgs_samples], filled=True,
                markers={'h': 0.67,
                         'Ωm': 0.25,
                         's8': 0.81})

# %%
g = plots.getSubplotPlotter(subplot_size=2.5)
g.triangle_plot(HaloWm_HM_samples, filled=True,
                markers={'h': 0.67,
                         'Ωm': 0.25,
                         's8': 0.81})

# %%
g = plots.getSubplotPlotter(subplot_size=2.5)
g.triangle_plot([new_EisHu_samples, new_Halofit_samples], filled=True,
                markers={'h': 0.67,
                         'Ωm': 0.25,
                         's8': 0.81})

# %%
np.std(new_Halofit["Ωm"])
# Out:
# 0.004888821651008822

# %%
np.std(new_EisHu["Ωm"])
# Out:
# 0.014955260714390673
