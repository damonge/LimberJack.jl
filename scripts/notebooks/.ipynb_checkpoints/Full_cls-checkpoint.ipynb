# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/home/jaime/PhD/LimberJack.jl/chains/carlos_chains/cl_cross_corr_v3_DES_K1000_all_mag_correctMag/"
cls_carlos_ND = np.load(path+"cl_cross_corr_bestfit_info.npz")
cls_carlos_SD = np.load(path+"cl_cross_corr_bestfit_info_copy.npz")
cls_carlos_FD = np.append(cls_carlos_SD['cls'], cls_carlos_ND['cls'])

# %%
meta = np.load("../data/FD/FD_meta.npz")
files = np.load("../data/FD/FD_files.npz")
cls_jaime = np.load("jaime_cls.npz")

# %%
list(files.keys())
# Out:
# ['ls_DESgc__0_0_DESgc__0_0',
#  'ls_DESgc__1_0_DESgc__1_0',
#  'ls_DESgc__2_0_DESgc__2_0',
#  'ls_DESgc__3_0_DESgc__3_0',
#  'ls_DESgc__4_0_DESgc__4_0',
#  'ls_DESgc__0_0_DESwl__0_e',
#  'ls_DESgc__0_0_DESwl__1_e',
#  'ls_DESgc__0_0_DESwl__2_e',
#  'ls_DESgc__0_0_DESwl__3_e',
#  'ls_DESgc__1_0_DESwl__0_e',
#  'ls_DESgc__1_0_DESwl__1_e',
#  'ls_DESgc__1_0_DESwl__2_e',
#  'ls_DESgc__1_0_DESwl__3_e',
#  'ls_DESgc__2_0_DESwl__0_e',
#  'ls_DESgc__2_0_DESwl__1_e',
#  'ls_DESgc__2_0_DESwl__2_e',
#  'ls_DESgc__2_0_DESwl__3_e',
#  'ls_DESgc__3_0_DESwl__0_e',
#  'ls_DESgc__3_0_DESwl__1_e',
#  'ls_DESgc__3_0_DESwl__2_e',
#  'ls_DESgc__3_0_DESwl__3_e',
#  'ls_DESgc__4_0_DESwl__0_e',
#  'ls_DESgc__4_0_DESwl__1_e',
#  'ls_DESgc__4_0_DESwl__2_e',
#  'ls_DESgc__4_0_DESwl__3_e',
#  'ls_DESgc__0_0_PLAcv_k',
#  'ls_DESgc__1_0_PLAcv_k',
#  'ls_DESgc__2_0_PLAcv_k',
#  'ls_DESgc__3_0_PLAcv_k',
#  'ls_DESgc__4_0_PLAcv_k',
#  'ls_DESwl__0_e_DESwl__0_e',
#  'ls_DESwl__0_e_DESwl__1_e',
#  'ls_DESwl__0_e_DESwl__2_e',
#  'ls_DESwl__0_e_DESwl__3_e',
#  'ls_DESwl__1_e_DESwl__1_e',
#  'ls_DESwl__1_e_DESwl__2_e',
#  'ls_DESwl__1_e_DESwl__3_e',
#  'ls_DESwl__2_e_DESwl__2_e',
#  'ls_DESwl__2_e_DESwl__3_e',
#  'ls_DESwl__3_e_DESwl__3_e',
#  'ls_DESwl__0_e_PLAcv_k',
#  'ls_DESwl__1_e_PLAcv_k',
#  'ls_DESwl__2_e_PLAcv_k',
#  'ls_DESwl__3_e_PLAcv_k',
#  'ls_eBOSS__0_0_eBOSS__0_0',
#  'ls_eBOSS__1_0_eBOSS__1_0',
#  'ls_eBOSS__0_0_PLAcv_k',
#  'ls_eBOSS__1_0_PLAcv_k',
#  'ls_DECALS__0_0_DECALS__0_0',
#  'ls_DECALS__1_0_DECALS__1_0',
#  'ls_DECALS__2_0_DECALS__2_0',
#  'ls_DECALS__3_0_DECALS__3_0',
#  'ls_DECALS__0_0_KiDS1000__0_e',
#  'ls_DECALS__0_0_KiDS1000__1_e',
#  'ls_DECALS__0_0_KiDS1000__2_e',
#  'ls_DECALS__0_0_KiDS1000__3_e',
#  'ls_DECALS__0_0_KiDS1000__4_e',
#  'ls_DECALS__1_0_KiDS1000__0_e',
#  'ls_DECALS__1_0_KiDS1000__1_e',
#  'ls_DECALS__1_0_KiDS1000__2_e',
#  'ls_DECALS__1_0_KiDS1000__3_e',
#  'ls_DECALS__1_0_KiDS1000__4_e',
#  'ls_DECALS__2_0_KiDS1000__0_e',
#  'ls_DECALS__2_0_KiDS1000__1_e',
#  'ls_DECALS__2_0_KiDS1000__2_e',
#  'ls_DECALS__2_0_KiDS1000__3_e',
#  'ls_DECALS__2_0_KiDS1000__4_e',
#  'ls_DECALS__3_0_KiDS1000__0_e',
#  'ls_DECALS__3_0_KiDS1000__1_e',
#  'ls_DECALS__3_0_KiDS1000__2_e',
#  'ls_DECALS__3_0_KiDS1000__3_e',
#  'ls_DECALS__3_0_KiDS1000__4_e',
#  'ls_DECALS__0_0_PLAcv_k',
#  'ls_DECALS__1_0_PLAcv_k',
#  'ls_DECALS__2_0_PLAcv_k',
#  'ls_DECALS__3_0_PLAcv_k',
#  'ls_KiDS1000__0_e_KiDS1000__0_e',
#  'ls_KiDS1000__0_e_KiDS1000__1_e',
#  'ls_KiDS1000__0_e_KiDS1000__2_e',
#  'ls_KiDS1000__0_e_KiDS1000__3_e',
#  'ls_KiDS1000__0_e_KiDS1000__4_e',
#  'ls_KiDS1000__1_e_KiDS1000__1_e',
#  'ls_KiDS1000__1_e_KiDS1000__2_e',
#  'ls_KiDS1000__1_e_KiDS1000__3_e',
#  'ls_KiDS1000__1_e_KiDS1000__4_e',
#  'ls_KiDS1000__2_e_KiDS1000__2_e',
#  'ls_KiDS1000__2_e_KiDS1000__3_e',
#  'ls_KiDS1000__2_e_KiDS1000__4_e',
#  'ls_KiDS1000__3_e_KiDS1000__3_e',
#  'ls_KiDS1000__3_e_KiDS1000__4_e',
#  'ls_KiDS1000__4_e_KiDS1000__4_e',
#  'ls_KiDS1000__0_e_PLAcv_k',
#  'ls_KiDS1000__1_e_PLAcv_k',
#  'ls_KiDS1000__2_e_PLAcv_k',
#  'ls_KiDS1000__3_e_PLAcv_k',
#  'ls_KiDS1000__4_e_PLAcv_k',
#  'nz_DESgc__0_0',
#  'nz_DESgc__1_0',
#  'nz_DESgc__2_0',
#  'nz_DESgc__3_0',
#  'nz_DESgc__4_0',
#  'nz_DESwl__0_e',
#  'nz_DESwl__1_e',
#  'nz_DESwl__2_e',
#  'nz_DESwl__3_e',
#  'nz_eBOSS__0_0',
#  'nz_eBOSS__1_0',
#  'nz_DECALS__0_0',
#  'nz_DECALS__1_0',
#  'nz_DECALS__2_0',
#  'nz_DECALS__3_0',
#  'nz_KiDS1000__0_e',
#  'nz_KiDS1000__1_e',
#  'nz_KiDS1000__2_e',
#  'nz_KiDS1000__3_e',
#  'nz_KiDS1000__4_e']

# %%
DESlen(files["ls_DESgc__0_0_DESgc__0_0"]) + len(files["ls_DESgc__0_0_DESgc__0_0"]) +
len(files["ls_DESgc__0_0_DESgc__0_0"])
# Out:
#   Input In [7]
#     len(files["ls_DESgc__0_0_DESgc__0_0"]) +
#                                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Lengths

# %%
len(cls_carlos_FD)
# Out:
# 1275

# %%
len(np.transpose(cls_jaime['cls_m']))
# Out:
# 1275

# %% [markdown]
# # Plots

# %%
data = meta["cls"]
err = np.sqrt(np.diag(meta["cov"]))
pairs = meta["pairs"]
idx = meta["idx"]
cls_best = cls_jaime['cls_best']
cls_m = cls_jaime['cls_m'][0]
cls_s = cls_jaime['cls_s'][0]
cls_carlos = cls_carlos_FD

# %%
cls_best
# Out:
# array([1.91120367e-04, 7.70400372e-05, 4.00766810e-05, ...,
#        3.73244352e-10, 3.18649290e-10, 2.70815869e-10])

# %% [markdown]
# ## DESgc-DESgc

# %%
figure, axis = plt.subplots(5, figsize=(5,14))
l = 0
for i in range(0,5):
    t1, t2 = pairs[l][0], pairs[l][1]
    axis[i].errorbar(files["ls_{}_{}".format(t1, t2)], 
                     data[idx[l]:idx[l+1]], 
                     yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
    axis[i].plot(files["ls_{}_{}".format(t1, t2)],
                 cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
    #axis[i].fill_between(files["ls_{}_{}".format(t1, t2)],
    #                    (cls_m+cls_s)[idx[l]:idx[l+1]],
    #                    (cls_m-cls_s)[idx[l]:idx[l+1]],
    #                    color="b", alpha=.5)
    #axis[i].plot(files["ls_{}_{}".format(t1, t2)],
    #             cls_carlos[idx[l]:idx[l+1]],
    #             "ro-", label="carlos")
    axis[i].set_title("{}_{}".format(t1,t2))
    l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 5

# %% [markdown]
# ## DESgc-DESwl

# %%
figure, axis = plt.subplots(5, 4, figsize=(16,16))
l = 5
for i in range(0,5):
    for j in range(0,4):
        t1, t2 = pairs[l][0], pairs[l][1]
        axis[i, j].errorbar(files["ls_{}_{}".format(t1, t2)], 
                     data[idx[l]:idx[l+1]], 
                     yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
        axis[i, j].plot(files["ls_{}_{}".format(t1, t2)],
                        cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
        #axis[i, j].fill_between(files["ls_{}_{}".format(t1, t2)],
        #                (cls_m+cls_s)[idx[l]:idx[l+1]],
        #                (cls_m-cls_s)[idx[l]:idx[l+1]],
        #                color="b", alpha=.5)
        #axis[i, j].plot(files["ls_{}_{}".format(t1, t2)],
        #                cls_carlos[idx[l]:idx[l+1]],
        #                "ro-", label="carlos")
        axis[i, j].set_title("{}_{}".format(t1,t2))
        l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 25

# %% [markdown]
# ## DESgc-CMBk

# %%
figure, axis = plt.subplots(5, figsize=(5,14))
l = 25
for i in range(0,5):
    t1, t2 = pairs[l][0], pairs[l][1]
    axis[i].errorbar(files["ls_{}_{}".format(t1, t2)], 
                     data[idx[l]:idx[l+1]], 
                     yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
    axis[i].plot(files["ls_{}_{}".format(t1, t2)],
                 cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
    #axis[i].fill_between(files["ls_{}_{}".format(t1, t2)],
    #                    (cls_m+cls_s)[idx[l]:idx[l+1]],
    #                    (cls_m-cls_s)[idx[l]:idx[l+1]],
    #                    color="b", alpha=.5)
    #axis[i].plot(files["ls_{}_{}".format(t1, t2)],
    #             cls_carlos[idx[l]:idx[l+1]],
    #            "ro-", label="carlos")
    axis[i].set_title("{}_{}".format(t1,t2))
    l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 30

# %% [markdown]
# ## DESwl-DESwl

# %%
figure, axis = plt.subplots(4, 4, figsize=(16,16))
l = 30
for i in range(0,4):
    for j in range(0,4):
        if j >= i:
            t1, t2 = pairs[l][0], pairs[l][1]
            axis[i, j].errorbar(files["ls_{}_{}".format(t1, t2)], 
                         data[idx[l]:idx[l+1]], 
                         yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
            axis[i, j].plot(files["ls_{}_{}".format(t1, t2)],
                            cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
            #axis[i, j].fill_between(files["ls_{}_{}".format(t1, t2)],
            #                (cls_m+cls_s)[idx[l]:idx[l+1]],
            #                (cls_m-cls_s)[idx[l]:idx[l+1]],
            #                color="b", alpha=.5)
            #axis[i, j].plot(files["ls_{}_{}".format(t1, t2)],
            #                cls_carlos[idx[l]:idx[l+1]],
            #                "ro-", label="carlos")
            axis[i, j].set_title("{}_{}".format(t1,t2))
            l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 40

# %% [markdown]
# ## DESwl-CMBk

# %%
figure, axis = plt.subplots(4, figsize=(5,14))
l = 40
for i in range(0,4):
    t1, t2 = pairs[l][0], pairs[l][1]
    axis[i].errorbar(files["ls_{}_{}".format(t1, t2)], 
                     data[idx[l]:idx[l+1]], 
                     yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
    axis[i].plot(files["ls_{}_{}".format(t1, t2)],
                 cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
    #axis[i].fill_between(files["ls_{}_{}".format(t1, t2)],
    #                    (cls_m+cls_s)[idx[l]:idx[l+1]],
    #                    (cls_m-cls_s)[idx[l]:idx[l+1]],
    #                    color="b", alpha=.5)
    #axis[i].plot(files["ls_{}_{}".format(t1, t2)],
    #             cls_carlos[idx[l]:idx[l+1]],
    #             "ro-", label="carlos")
    axis[i].set_title("{}_{}".format(t1,t2))
    l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 44

# %% [markdown]
# ## eBOSS-eBOSS

# %%
figure, axis = plt.subplots(2, figsize=(5,5))
l = 44
for i in range(0,2):
    t1, t2 = pairs[l][0], pairs[l][1]
    axis[i].errorbar(files["ls_{}_{}".format(t1, t2)], 
                     data[idx[l]:idx[l+1]], 
                     yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
    axis[i].plot(files["ls_{}_{}".format(t1, t2)],
                 cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
    #axis[i].fill_between(files["ls_{}_{}".format(t1, t2)],
    #                    (cls_m+cls_s)[idx[l]:idx[l+1]],
    #                    (cls_m-cls_s)[idx[l]:idx[l+1]],
    #                    color="b", alpha=.5)
    #axis[i].plot(files["ls_{}_{}".format(t1, t2)],
    #             cls_carlos[idx[l]:idx[l+1]],
    #             "ro-", label="carlos")
    axis[i].set_title("{}_{}".format(t1,t2))
    l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 46

# %% [markdown]
# ## eBOSS-CMBk

# %%
figure, axis = plt.subplots(2, figsize=(5,5))
l = 46
for i in range(0,2):
    t1, t2 = pairs[l][0], pairs[l][1]
    axis[i].errorbar(files["ls_{}_{}".format(t1, t2)], 
                     data[idx[l]:idx[l+1]], 
                     yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
    axis[i].plot(files["ls_{}_{}".format(t1, t2)],
                 cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
    #axis[i].fill_between(files["ls_{}_{}".format(t1, t2)],
    #                    (cls_m+cls_s)[idx[l]:idx[l+1]],
    #                    (cls_m-cls_s)[idx[l]:idx[l+1]],
    #                    color="b", alpha=.5)
    #axis[i].plot(files["ls_{}_{}".format(t1, t2)],
    #             cls_carlos[idx[l]:idx[l+1]],
    #             "ro-", label="carlos")
    axis[i].set_title("{}_{}".format(t1,t2))
    l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 48

# %% [markdown]
# ## DECALS-DECALS

# %%
figure, axis = plt.subplots(4, figsize=(5,14))
l = 48
for i in range(0,4):
    t1, t2 = pairs[l][0], pairs[l][1]
    axis[i].errorbar(files["ls_{}_{}".format(t1, t2)], 
                     data[idx[l]:idx[l+1]], 
                     yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
    axis[i].plot(files["ls_{}_{}".format(t1, t2)],
                 cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
    #axis[i].fill_between(files["ls_{}_{}".format(t1, t2)],
    #                    (cls_m+cls_s)[idx[l]:idx[l+1]],
    #                    (cls_m-cls_s)[idx[l]:idx[l+1]],
    #                    color="b", alpha=.5)
    #axis[i].plot(files["ls_{}_{}".format(t1, t2)],
    #             cls_carlos[idx[l]:idx[l+1]],
    #             "ro-", label="carlos")
    axis[i].set_title("{}_{}".format(t1,t2))
    l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 52

# %% [markdown]
# ## DECALS-KiDS1000

# %%
figure, axis = plt.subplots(4, 5, figsize=(16,16))
l = 52
for i in range(0,4):
    for j in range(0,5):
        t1, t2 = pairs[l][0], pairs[l][1]
        axis[i, j].errorbar(files["ls_{}_{}".format(t1, t2)], 
                     data[idx[l]:idx[l+1]], 
                     yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
        axis[i, j].plot(files["ls_{}_{}".format(t1, t2)],
                        cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
        #axis[i, j].fill_between(files["ls_{}_{}".format(t1, t2)],
        #                (cls_m+cls_s)[idx[l]:idx[l+1]],
        #                (cls_m-cls_s)[idx[l]:idx[l+1]],
        #                color="b", alpha=.5)
        #axis[i, j].plot(files["ls_{}_{}".format(t1, t2)],
        #                cls_carlos[idx[l]:idx[l+1]],
        #                "ro-", label="carlos")
        axis[i, j].set_title("{}_{}".format(t1,t2))
        l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 72

# %% [markdown]
# ## DECALS-CMBk

# %%
figure, axis = plt.subplots(4, figsize=(5,14))
l = 72
for i in range(0,4):
    t1, t2 = pairs[l][0], pairs[l][1]
    axis[i].errorbar(files["ls_{}_{}".format(t1, t2)], 
                     data[idx[l]:idx[l+1]], 
                     yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
    axis[i].plot(files["ls_{}_{}".format(t1, t2)],
                 cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
    #axis[i].fill_between(files["ls_{}_{}".format(t1, t2)],
    #                    (cls_m+cls_s)[idx[l]:idx[l+1]],
    #                    (cls_m-cls_s)[idx[l]:idx[l+1]],
    #                    color="b", alpha=.5)
    #axis[i].plot(files["ls_{}_{}".format(t1, t2)],
    #             cls_carlos[idx[l]:idx[l+1]],
    #             "ro-", label="carlos")
    axis[i].set_title("{}_{}".format(t1,t2))
    l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 76

# %% [markdown]
# ## KiDS1000-KiDS1000

# %%
figure, axis = plt.subplots(5, 5, figsize=(16,16))
l = 76
for i in range(0,5):
    for j in range(0,5):
        if j >= i:
            t1, t2 = pairs[l][0], pairs[l][1]
            axis[i, j].errorbar(files["ls_{}_{}".format(t1, t2)], 
                         data[idx[l]:idx[l+1]], 
                         yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
            axis[i, j].plot(files["ls_{}_{}".format(t1, t2)],
                            cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
            #axis[i, j].fill_between(files["ls_{}_{}".format(t1, t2)],
            #                (cls_m+cls_s)[idx[l]:idx[l+1]],
            #                (cls_m-cls_s)[idx[l]:idx[l+1]],
            #                color="b", alpha=.5)
            #axis[i, j].plot(files["ls_{}_{}".format(t1, t2)],
            #                cls_carlos[idx[l]:idx[l+1]],
            #                "ro-", label="carlos")
            axis[i, j].set_title("{}_{}".format(t1,t2))
            l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 91

# %% [markdown]
# ## KiDS1000-CMBk

# %%
figure, axis = plt.subplots(5, figsize=(5,14))
l = 91
for i in range(0,5):
    t1, t2 = pairs[l][0], pairs[l][1]
    axis[i].errorbar(files["ls_{}_{}".format(t1, t2)], 
                     data[idx[l]:idx[l+1]], 
                     yerr=err[idx[l]:idx[l+1]], fmt='gs', label='Data')
    axis[i].plot(files["ls_{}_{}".format(t1, t2)],
                 cls_best[idx[l]:idx[l+1]], 'bo-', label="jaime")
    #axis[i].fill_between(files["ls_{}_{}".format(t1, t2)],
    #                    (cls_m+cls_s)[idx[l]:idx[l+1]],
    #                    (cls_m-cls_s)[idx[l]:idx[l+1]],
    #                    color="b", alpha=.5)
    #axis[i].plot(files["ls_{}_{}".format(t1, t2)],
    #             cls_carlos[idx[l]:idx[l+1]],
    #             "ro-", label="carlos")
    axis[i].set_title("{}_{}".format(t1,t2))
    l += 1
plt.legend()
plt.show()
print(l)
# Out:
# 96
